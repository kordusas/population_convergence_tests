# %%
from _common.functions import  plot_statistics_variation, history_score_probability
import numpy as np

# %% [markdown]
# # Uniform distirbution convergence tests

# %%
# create uniform distirbution

population = np.random.uniform(0,10,int(1e7))
weights = np.random.uniform(0,1,len(population))
print(len(population))
# Out:
# 10000000

# %% [markdown]
# ## Testing History Score Probability

# %%
# Linear spacing from 1 to np.sum(mask)
linear_spacing = np.linspace(1, np.size(population), num=100, dtype=int)

# Logarithmic spacing from 10^1 to 10^6, scaled by 2
logarithmic_spacing = np.logspace(1, 6, num=100, dtype=int) * 3
print(logarithmic_spacing[-1])
x,y = history_score_probability(population, weights)
# Out:
# 3000000

# %% [markdown]
# ## Testing Relative Mean, error and Variance of Variance convergence

# %%
axs = plot_statistics_variation(population, weights,
                          logarithmic_spacing)
axs[1].set_yscale("log")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 97.43it/s]
